# %%
import traopy_builder as trab
import traopy_util as trau

print(dir(trab))
print(dir(trab.MyStruct))
print(dir(trau.v0.JudgeStatus))
judge_status = trau.v0.JudgeStatus
print(str(judge_status))
print(trau.v0.JudgeStatus)
# Out:
# ['Dependency', 'EmptyDirectory', 'Execution', 'LocalJudge', 'MyStruct', 'ProcedureBuilder', 'ResourceKind', 'RuntimeText', 'Text', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'lowlevel']
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__']
# ['AC', 'CE', 'MLE', 'OLE', 'RE', 'TLE', 'WA', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__int__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__']
# ...
